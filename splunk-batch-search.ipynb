# %%
#!/usr/bin/python3
from __future__ import absolute_import
from __future__ import print_function
import splunklib.client as client
import splunklib.results as results
import sys
from time import sleep

HOST = "localhost"
PORT = 8089
USERNAME = "admin"
PASSWORD = "welcome1"
TOKEN="eyJraWQiOiJzcGx1bmsuc2VjcmV0IiwiYWxnIjoiSFM1MTIiLCJ2ZXIiOiJ2MiIsInR0eXAiOiJzdGF0aWMifQ..b0SRVIBCn3mEy3kXuE5BXyrNruW392Sch52QzWeCQ2n5NukW3dkT8FdH_YvQNwAr1DdP7JUROgdHdhCu2cT18A"
searchquery_export = 'search index=_internal management  source="/Applications/Splunk/var/log/splunk/metrics.log" | head 200 | table _raw'

# Create a Service instance and log in
service = client.connect(
    host=HOST,
    port=PORT,
    splunkToken=TOKEN,
    autologin=True)


kwargs_export = {"earliest_time": "-1h",
                 "latest_time": "now",
                 "search_mode": "normal",
                 "output_mode": "json"}



exportsearch_results = service.jobs.export(searchquery_export, **kwargs_export)

# Get the results and display them using the JSONResultsReader
reader = results.JSONResultsReader(exportsearch_results)
for result in reader:
    if isinstance(result, dict):
        print(result)
    elif isinstance(result, results.Message):
        # Diagnostic messages may be returned in the results
        print(result)

# Print whether results are a preview from a running search
print("is_preview = %s " % reader.is_preview)
# Out:
# {'_raw': '09-29-2022 10:32:32.676 -0400 INFO  Metrics - group=dutycycle, name=management, thread=webui, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.676 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tailreader0, ratio=0.002'}
# {'_raw': '09-29-2022 10:32:32.675 -0400 INFO  Metrics - group=dutycycle, name=management, thread=journal-compress, ratio=0.000, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.675 -0400 INFO  Metrics - group=dutycycle, name=management, thread=idle_http_client, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.674 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fifo, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.673 -0400 INFO  Metrics - group=dutycycle, name=management, thread=batchreader0, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.673 -0400 INFO  Metrics - group=dutycycle, name=management, thread=archivereader, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.672 -0400 INFO  Metrics - group=dutycycle, name=management, thread=udpinputprocessor, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.671 -0400 INFO  Metrics - group=dutycycle, name=management, thread=telemetrymetricbuffer, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.671 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcppqreaderthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.670 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcpouteloop, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.670 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcplistener, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.669 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcpchannelthread, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.667 -0400 INFO  Metrics - group=dutycycle, name=management, thread=splunkconfigchangewatcherthread, ratio=0.001'}
# {'_raw': '09-29-2022 10:32:32.667 -0400 INFO  Metrics - group=dutycycle, name=management, thread=shutdown, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.665 -0400 INFO  Metrics - group=dutycycle, name=management, thread=searchprocessreaper, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.665 -0400 INFO  Metrics - group=dutycycle, name=management, thread=schedulerthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.664 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savedsearchhistorythread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.662 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savedsearchfetcher, ratio=0.003'}
# {'_raw': '09-29-2022 10:32:32.662 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savependinguploadstodiskthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.661 -0400 INFO  Metrics - group=dutycycle, name=management, thread=recreateindexesthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.661 -0400 INFO  Metrics - group=dutycycle, name=management, thread=queueservicethread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.660 -0400 INFO  Metrics - group=dutycycle, name=management, thread=preforkedsearchesmanager-0, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.659 -0400 INFO  Metrics - group=dutycycle, name=management, thread=persistentscriptio, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.658 -0400 INFO  Metrics - group=dutycycle, name=management, thread=mongodlogthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.658 -0400 INFO  Metrics - group=dutycycle, name=management, thread=maintailingthread, ratio=0.001'}
# {'_raw': '09-29-2022 10:32:32.657 -0400 INFO  Metrics - group=dutycycle, name=management, thread=kvstoreconfigurationthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.656 -0400 INFO  Metrics - group=dutycycle, name=management, thread=kvstorebackupthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.655 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-7, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.655 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-6, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.654 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-5, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.654 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-4, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.653 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-3, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.653 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-2, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.652 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-1, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.652 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-0, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.651 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexerservice, ratio=0.002'}
# {'_raw': '09-29-2022 10:32:32.651 -0400 INFO  Metrics - group=dutycycle, name=management, thread=idatado_collector, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.650 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputservermanagementthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.650 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputserverdatathread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.649 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputqueuethread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.649 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-7, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.649 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-6, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.648 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-5, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.648 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-4, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.648 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-3, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-2, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-1, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-0, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.646 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdispatch, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.646 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fwddatareceiverthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.645 -0400 INFO  Metrics - group=dutycycle, name=management, thread=federatedheartbeat, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.645 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fsupdaterthread, ratio=0.177'}
# {'_raw': '09-29-2022 10:32:32.644 -0400 INFO  Metrics - group=dutycycle, name=management, thread=execprocessor, ratio=0.001'}
# {'_raw': '09-29-2022 10:32:32.644 -0400 INFO  Metrics - group=dutycycle, name=management, thread=distributedrestcallereventloopthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.644 -0400 INFO  Metrics - group=dutycycle, name=management, thread=distributedpeermonitorthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.643 -0400 INFO  Metrics - group=dutycycle, name=management, thread=dispatchreaper, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.643 -0400 INFO  Metrics - group=dutycycle, name=management, thread=dispatchlogthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.643 -0400 INFO  Metrics - group=dutycycle, name=management, thread=diagdownloadthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.642 -0400 INFO  Metrics - group=dutycycle, name=management, thread=collectioncachebookkeepingthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:32.642 -0400 INFO  Metrics - group=dutycycle, name=management, thread=callbackrunnerthread, ratio=0.002'}
# {'_raw': '09-29-2022 10:32:32.641 -0400 INFO  Metrics - group=dutycycle, name=management, thread=cachemanagerusagemetrics, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.676 -0400 INFO  Metrics - group=dutycycle, name=management, thread=webui, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.676 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tailreader0, ratio=0.015'}
# {'_raw': '09-29-2022 10:32:01.676 -0400 INFO  Metrics - group=dutycycle, name=management, thread=journal-compress, ratio=0.000, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.676 -0400 INFO  Metrics - group=dutycycle, name=management, thread=idle_http_client, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.675 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fifo, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.675 -0400 INFO  Metrics - group=dutycycle, name=management, thread=batchreader0, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.675 -0400 INFO  Metrics - group=dutycycle, name=management, thread=archivereader, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.675 -0400 INFO  Metrics - group=dutycycle, name=management, thread=udpinputprocessor, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.674 -0400 INFO  Metrics - group=dutycycle, name=management, thread=telemetrymetricbuffer, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.674 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcppqreaderthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.674 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcpouteloop, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.673 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcplistener, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.673 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcpchannelthread, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.673 -0400 INFO  Metrics - group=dutycycle, name=management, thread=splunkconfigchangewatcherthread, ratio=0.001'}
# {'_raw': '09-29-2022 10:32:01.672 -0400 INFO  Metrics - group=dutycycle, name=management, thread=shutdown, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.672 -0400 INFO  Metrics - group=dutycycle, name=management, thread=searchprocessreaper, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.671 -0400 INFO  Metrics - group=dutycycle, name=management, thread=schedulerthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.670 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savedsearchhistorythread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.670 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savedsearchfetcher, ratio=0.005'}
# {'_raw': '09-29-2022 10:32:01.669 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savependinguploadstodiskthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.669 -0400 INFO  Metrics - group=dutycycle, name=management, thread=recreateindexesthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.668 -0400 INFO  Metrics - group=dutycycle, name=management, thread=queueservicethread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.667 -0400 INFO  Metrics - group=dutycycle, name=management, thread=preforkedsearchesmanager-0, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.667 -0400 INFO  Metrics - group=dutycycle, name=management, thread=persistentscriptio, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.666 -0400 INFO  Metrics - group=dutycycle, name=management, thread=mongodlogthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.666 -0400 INFO  Metrics - group=dutycycle, name=management, thread=maintailingthread, ratio=0.003'}
# {'_raw': '09-29-2022 10:32:01.665 -0400 INFO  Metrics - group=dutycycle, name=management, thread=kvstoreconfigurationthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.665 -0400 INFO  Metrics - group=dutycycle, name=management, thread=kvstorebackupthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.664 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-7, ratio=0.001'}
# {'_raw': '09-29-2022 10:32:01.663 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-6, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.663 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-5, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.662 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-4, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.661 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-3, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.661 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-2, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.660 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-1, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.660 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-0, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.659 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexerservice, ratio=0.012'}
# {'_raw': '09-29-2022 10:32:01.658 -0400 INFO  Metrics - group=dutycycle, name=management, thread=idatado_collector, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.658 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputservermanagementthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.657 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputserverdatathread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.656 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputqueuethread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.655 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-7, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.655 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-6, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.654 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-5, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.653 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-4, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.653 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-3, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.652 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-2, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.652 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-1, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.651 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-0, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.650 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdispatch, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.649 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fwddatareceiverthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.649 -0400 INFO  Metrics - group=dutycycle, name=management, thread=federatedheartbeat, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.648 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fsupdaterthread, ratio=1.000'}
# {'_raw': '09-29-2022 10:32:01.648 -0400 INFO  Metrics - group=dutycycle, name=management, thread=execprocessor, ratio=0.004'}
# {'_raw': '09-29-2022 10:32:01.648 -0400 INFO  Metrics - group=dutycycle, name=management, thread=distributedrestcallereventloopthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=distributedpeermonitorthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=dispatchreaper, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=dispatchlogthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.647 -0400 INFO  Metrics - group=dutycycle, name=management, thread=diagdownloadthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.646 -0400 INFO  Metrics - group=dutycycle, name=management, thread=collectioncachebookkeepingthread, ratio=0.000'}
# {'_raw': '09-29-2022 10:32:01.646 -0400 INFO  Metrics - group=dutycycle, name=management, thread=callbackrunnerthread, ratio=0.014'}
# {'_raw': '09-29-2022 10:32:01.646 -0400 INFO  Metrics - group=dutycycle, name=management, thread=cachemanagerusagemetrics, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.817 -0400 INFO  Metrics - group=dutycycle, name=management, thread=webui, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.815 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tailreader0, ratio=0.004'}
# {'_raw': '09-29-2022 09:35:52.814 -0400 INFO  Metrics - group=dutycycle, name=management, thread=journal-compress, ratio=0.000, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.813 -0400 INFO  Metrics - group=dutycycle, name=management, thread=idle_http_client, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.812 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fifo, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.811 -0400 INFO  Metrics - group=dutycycle, name=management, thread=batchreader0, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.810 -0400 INFO  Metrics - group=dutycycle, name=management, thread=archivereader, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.808 -0400 INFO  Metrics - group=dutycycle, name=management, thread=udpinputprocessor, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.807 -0400 INFO  Metrics - group=dutycycle, name=management, thread=telemetrymetricbuffer, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.806 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcppqreaderthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.805 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcpouteloop, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.804 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcplistener, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.802 -0400 INFO  Metrics - group=dutycycle, name=management, thread=tcpchannelthread, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.801 -0400 INFO  Metrics - group=dutycycle, name=management, thread=splunkconfigchangewatcherthread, ratio=0.001'}
# {'_raw': '09-29-2022 09:35:52.800 -0400 INFO  Metrics - group=dutycycle, name=management, thread=shutdown, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.798 -0400 INFO  Metrics - group=dutycycle, name=management, thread=searchprocessreaper, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.797 -0400 INFO  Metrics - group=dutycycle, name=management, thread=schedulerthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.796 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savedsearchhistorythread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.795 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savedsearchfetcher, ratio=0.009'}
# {'_raw': '09-29-2022 09:35:52.794 -0400 INFO  Metrics - group=dutycycle, name=management, thread=savependinguploadstodiskthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.792 -0400 INFO  Metrics - group=dutycycle, name=management, thread=recreateindexesthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.791 -0400 INFO  Metrics - group=dutycycle, name=management, thread=queueservicethread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.790 -0400 INFO  Metrics - group=dutycycle, name=management, thread=preforkedsearchesmanager-0, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.789 -0400 INFO  Metrics - group=dutycycle, name=management, thread=persistentscriptio, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.788 -0400 INFO  Metrics - group=dutycycle, name=management, thread=mongodlogthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.786 -0400 INFO  Metrics - group=dutycycle, name=management, thread=maintailingthread, ratio=0.013'}
# {'_raw': '09-29-2022 09:35:52.785 -0400 INFO  Metrics - group=dutycycle, name=management, thread=kvstoreconfigurationthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.784 -0400 INFO  Metrics - group=dutycycle, name=management, thread=kvstorebackupthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.783 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-7, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.782 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-6, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.781 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-5, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.779 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-4, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.778 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-3, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.777 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-2, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.776 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-1, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.775 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexertpoolworker-0, ratio=0.001'}
# {'_raw': '09-29-2022 09:35:52.774 -0400 INFO  Metrics - group=dutycycle, name=management, thread=indexerservice, ratio=0.013'}
# {'_raw': '09-29-2022 09:35:52.772 -0400 INFO  Metrics - group=dutycycle, name=management, thread=idatado_collector, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.771 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputservermanagementthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.770 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputserverdatathread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.769 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpinputqueuethread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.768 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-7, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.767 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-6, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.765 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-5, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.763 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-4, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.761 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-3, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.759 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-2, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.758 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-1, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.757 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdedicatediothread-0, ratio=0.000, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.756 -0400 INFO  Metrics - group=dutycycle, name=management, thread=httpdispatch, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.755 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fwddatareceiverthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.753 -0400 INFO  Metrics - group=dutycycle, name=management, thread=federatedheartbeat, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.752 -0400 INFO  Metrics - group=dutycycle, name=management, thread=fsupdaterthread, ratio=1.000'}
# {'_raw': '09-29-2022 09:35:52.751 -0400 INFO  Metrics - group=dutycycle, name=management, thread=execprocessor, ratio=0.002'}
# {'_raw': '09-29-2022 09:35:52.750 -0400 INFO  Metrics - group=dutycycle, name=management, thread=distributedrestcallereventloopthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.749 -0400 INFO  Metrics - group=dutycycle, name=management, thread=distributedpeermonitorthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.747 -0400 INFO  Metrics - group=dutycycle, name=management, thread=dispatchreaper, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.746 -0400 INFO  Metrics - group=dutycycle, name=management, thread=dispatchlogthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.745 -0400 INFO  Metrics - group=dutycycle, name=management, thread=diagdownloadthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.744 -0400 INFO  Metrics - group=dutycycle, name=management, thread=collectioncachebookkeepingthread, ratio=0.000'}
# {'_raw': '09-29-2022 09:35:52.742 -0400 INFO  Metrics - group=dutycycle, name=management, thread=callbackrunnerthread, ratio=0.013'}
# {'_raw': '09-29-2022 09:35:52.741 -0400 INFO  Metrics - group=dutycycle, name=management, thread=cachemanagerusagemetrics, ratio=0.000'}
# is_preview = False
